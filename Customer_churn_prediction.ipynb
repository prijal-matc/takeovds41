# %% [markdown]
# <a href="https://colab.research.google.com/github/prijal-matc/takeovds41/blob/main/Customer_churn_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
churn1 = pd.read_csv('/content/churn-bigml-20.csv')
churn2 = pd.read_csv('/content/churn-bigml-80.csv')

print(churn1.head)
print(churn2.head)
# Out:
# <bound method NDFrame.head of     State  Account length  Area code International plan Voice mail plan  \
# 0      LA             117        408                 No              No
# 1      IN              65        415                 No              No
# 2      NY             161        415                 No              No
# 3      SC             111        415                 No              No
# 4      HI              49        510                 No              No
# ..    ...             ...        ...                ...             ...
# 662    WI             114        415                 No             Yes
# 663    AL             106        408                 No             Yes
# 664    VT              60        415                 No              No
# 665    WV             159        415                 No              No
# 666    CT             184        510                Yes              No
#
#      Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
print(churn1.columns)
print(churn2.columns)
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
churn = churn1.append(churn2)
# Out:
# <ipython-input-7-bf91ea479e7f>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   churn = churn1.append(churn2)

# %%
churn.info
# Out:
# <bound method DataFrame.info of      State  Account length  Area code International plan Voice mail plan  \
# 0       LA             117        408                 No              No
# 1       IN              65        415                 No              No
# 2       NY             161        415                 No              No
# 3       SC             111        415                 No              No
# 4       HI              49        510                 No              No
# ...    ...             ...        ...                ...             ...
# 2661    SC              79        415                 No              No
# 2662    AZ             192        415                 No             Yes
# 2663    WV              68        415                 No              No
# 2664    RI              28        510                 No              No
# 2665    TN              74        415                 No             Yes
#
# ...

# %%
churn.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
churn
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       LA             117        408                 No              No
# 1       IN              65        415                 No              No
# 2       NY             161        415                 No              No
# 3       SC             111        415                 No              No
# 4       HI              49        510                 No              No
# ...    ...             ...        ...                ...             ...
# 2661    SC              79        415                 No              No
# 2662    AZ             192        415                 No             Yes
# 2663    WV              68        415                 No              No
# 2664    RI              28        510                 No              No
# 2665    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
churn.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
churn.shape
# Out:
# (3333, 20)

# %%
churn.size
# Out:
# 66660

# %%
churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3333 entries, 0 to 2665
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %%
churn.isna().sum()
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %%
churn.nunique()
# Out:
# State                       51
# Account length             212
# Area code                    3
# International plan           2
# Voice mail plan              2
# Number vmail messages       46
# Total day minutes         1667
# Total day calls            119
# Total day charge          1667
# Total eve minutes         1611
# Total eve calls            123
# Total eve charge          1440
# Total night minutes       1591
# Total night calls          120
# Total night charge         933
# Total intl minutes         162
# Total intl calls            21
# Total intl charge          162
# Customer service calls      10
# Churn                        2
# dtype: int64

# %%
churn.groupby('Account length').Churn.sum()
# Out:
# Account length
# 1      1
# 2      1
# 3      0
# 4      0
# 5      0
#       ..
# 221    0
# 224    1
# 225    1
# 232    0
# 243    0
# Name: Churn, Length: 212, dtype: int64

# %%
churn.groupby('Account length')['Total day charge'].sum()
# Out:
# Account length
# 1      231.16
# 2       22.46
# 3      113.99
# 4       24.70
# 5       33.86
#         ...
# 221     30.69
# 224     48.10
# 225     59.18
# 232     28.15
# 243     16.24
# Name: Total day charge, Length: 212, dtype: float64

# %%
churn.groupby('Account length')['Total day calls'].sum()
# Out:
# Account length
# 1      785
# 2       42
# 3      548
# 4       89
# 5      106
#       ...
# 221     85
# 224    232
# 225    248
# 232    104
# 243     92
# Name: Total day calls, Length: 212, dtype: int64

# %%
churn.groupby('Account length')['Total night charge'].sum()
# Out:
# Account length
# 1      66.86
# 2       8.67
# 3      46.02
# 4       9.27
# 5       9.63
#        ...
# 221     9.26
# 224    19.33
# 225    19.26
# 232     5.32
# 243    11.89
# Name: Total night charge, Length: 212, dtype: float64

# %%
churn.groupby('Area code')['Total day charge'].sum()
# Out:
# Area code
# 408    25240.79
# 415    51092.06
# 510    25531.32
# Name: Total day charge, dtype: float64

# %%
churn.groupby('Area code')['Total intl charge'].sum()
# Out:
# Area code
# 408    2291.71
# 415    4622.84
# 510    2299.80
# Name: Total intl charge, dtype: float64

# %%
churn.groupby('Area code')['Total night charge'].sum()
# Out:
# Area code
# 408     7512.49
# 415    15046.92
# 510     7568.66
# Name: Total night charge, dtype: float64

# %%
churn.groupby('Area code')['Total eve calls'].sum()
# Out:
# Area code
# 408     83623
# 415    166334
# 510     83724
# Name: Total eve calls, dtype: int64

# %%
churn.groupby('Total day calls')['Total day charge'].sum()
# Out:
# Total day calls
# 0       0.00
# 30     36.84
# 35     24.57
# 36     31.59
# 40     75.22
#        ...
# 157    32.18
# 158    52.50
# 160    33.68
# 163    12.05
# 165    26.25
# Name: Total day charge, Length: 119, dtype: float64

# %%
churn.groupby('Total night calls')['Total night charge'].sum()
# Out:
# Total night calls
# 33     10.58
# 36     10.01
# 38      9.16
# 42     13.72
# 44      7.61
#        ...
# 157    18.44
# 158     6.35
# 164     7.60
# 166     9.95
# 175    11.85
# Name: Total night charge, Length: 120, dtype: float64

# %%
churn.groupby('Total night calls')['Total intl charge'].sum()
# Out:
# Total night calls
# 33     4.35
# 36     3.24
# 38     1.81
# 42     5.70
# 44     2.32
#        ...
# 157    5.51
# 158    3.05
# 164    3.24
# 166    2.38
# 175    1.59
# Name: Total intl charge, Length: 120, dtype: float64

# %%
churn.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %%
churn.nunique()
# Out:
# State                       51
# Account length             212
# Area code                    3
# International plan           2
# Voice mail plan              2
# Number vmail messages       46
# Total day minutes         1667
# Total day calls            119
# Total day charge          1667
# Total eve minutes         1611
# Total eve calls            123
# Total eve charge          1440
# Total night minutes       1591
# Total night calls          120
# Total night charge         933
# Total intl minutes         162
# Total intl calls            21
# Total intl charge          162
# Customer service calls      10
# Churn                        2
# dtype: int64

# %%
churn.groupby('Account length').Churn.agg(['max', 'min', 'mean'])
# Out:
#                   max    min   mean
# Account length
# 1                True  False  0.125
# 2                True   True  1.000
# 3               False  False  0.000
# 4               False  False  0.000
# 5               False  False  0.000
# ...               ...    ...    ...
# 221             False  False  0.000
# 224              True  False  0.500
# 225              True  False  0.500
# 232             False  False  0.000
# 243             False  False  0.000
#
# [212 rows x 3 columns]

# %%
churn.groupby(['Account length', 'Area code']).agg(['max', 'min', 'mean'])
# Out:
# <ipython-input-50-10bb24922818>:1: FutureWarning: ['State', 'International plan', 'Voice mail plan'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   churn.groupby(['Account length', 'Area code']).agg(['max', 'min', 'mean'])
#                          Number vmail messages                 \
#                                            max min       mean
# Account length Area code
# 1              408                          26   0   8.666667
#                415                          30   0  11.200000
# 2              415                           0   0   0.000000
# 3              408                           0   0   0.000000
#                415                          36   0  18.000000
# ...                                        ...  ..        ...
# 221            510                          24  24  24.000000
# 224            510                           0   0   0.000000
# ...

# %%
churn
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       LA             117        408                 No              No
# 1       IN              65        415                 No              No
# 2       NY             161        415                 No              No
# 3       SC             111        415                 No              No
# 4       HI              49        510                 No              No
# ...    ...             ...        ...                ...             ...
# 2661    SC              79        415                 No              No
# 2662    AZ             192        415                 No             Yes
# 2663    WV              68        415                 No              No
# 2664    RI              28        510                 No              No
# 2665    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
plt.plot(churn.Churn)

# %%
plt.plot(churn['Account length'])

# %%
plt.plot(churn['Total day calls'])

# %%
plt.plot(churn['Total night calls'])

# %%
plt.plot(churn['Total intl charge'])

# %%
plt.scatter(churn.index, churn['Total day calls'])

# %%
plt.scatter(churn.index, churn['Account length'])

# %%
plt.scatter(churn.index, churn['Total night charge'])

# %%
plt.bar(churn.index, churn['Total eve calls'])
# Out:
# <BarContainer object of 3333 artists>

# %%
plt.bar(churn.index, churn['Customer service calls'])
# Out:
# <BarContainer object of 3333 artists>

# %%
plt.bar(churn.index, churn['Number vmail messages'])
# Out:
# <BarContainer object of 3333 artists>

# %%
churn[churn.State.isna()]
# Out:
# Empty DataFrame
# Columns: [State, Account length, Area code, International plan, Voice mail plan, Number vmail messages, Total day minutes, Total day calls, Total day charge, Total eve minutes, Total eve calls, Total eve charge, Total night minutes, Total night calls, Total night charge, Total intl minutes, Total intl calls, Total intl charge, Customer service calls, Churn]
# Index: []

# %%
churn[churn['Total day charge'].isna()]
# Out:
# Empty DataFrame
# Columns: [State, Account length, Area code, International plan, Voice mail plan, Number vmail messages, Total day minutes, Total day calls, Total day charge, Total eve minutes, Total eve calls, Total eve charge, Total night minutes, Total night calls, Total night charge, Total intl minutes, Total intl calls, Total intl charge, Customer service calls, Churn]
# Index: []

# %%
churn.shape
# Out:
# (3333, 20)

# %%
churn.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %%
churn.duplicated().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2661    False
# 2662    False
# 2663    False
# 2664    False
# 2665    False
# Length: 3333, dtype: bool>

# %%
churn.dtypes
# Out:
# State                      object
# Account length              int64
# Area code                   int64
# International plan         object
# Voice mail plan            object
# Number vmail messages       int64
# Total day minutes         float64
# Total day calls             int64
# Total day charge          float64
# Total eve minutes         float64
# Total eve calls             int64
# Total eve charge          float64
# Total night minutes       float64
# Total night calls           int64
# Total night charge        float64
# Total intl minutes        float64
# Total intl calls            int64
# Total intl charge         float64
# Customer service calls      int64
# Churn                        bool
# dtype: object

# %%
print(churn.State.value_counts())
# Out:
# WV    106
# MN     84
# NY     83
# AL     80
# OR     78
# OH     78
# WI     78
# VA     77
# WY     77
# CT     74
# MI     73
# ID     73
# VT     73
# TX     72
# UT     72
# IN     71
# KS     70
# MD     70
# MT     68
# NJ     68
# NC     68
# NV     66
# WA     66
# CO     66
# MA     65
# MS     65
# RI     65
# AZ     64
# FL     63
# MO     63
# NM     62
# ND     62
# ME     62
# OK     61
# NE     61
# DE     61
# SD     60
# SC     60
# KY     59
# IL     58
# NH     56
# AR     55
# GA     54
# DC     54
# HI     53
# TN     53
# AK     52
# LA     51
# PA     45
# IA     44
# CA     34
# Name: State, dtype: int64

# %%
print(churn.State.value_counts())
print()
print(churn.State.min())
# Out:
# WV    106
# MN     84
# NY     83
# AL     80
# OR     78
# OH     78
# WI     78
# VA     77
# WY     77
# CT     74
# MI     73
# ID     73
# VT     73
# TX     72
# UT     72
# IN     71
# KS     70
# MD     70
# MT     68
# NJ     68
# NC     68
# NV     66
# WA     66
# CO     66
# MA     65
# MS     65
# RI     65
# AZ     64
# FL     63
# MO     63
# NM     62
# ND     62
# ME     62
# OK     61
# NE     61
# DE     61
# SD     60
# SC     60
# KY     59
# IL     58
# NH     56
# AR     55
# GA     54
# DC     54
# HI     53
# TN     53
# AK     52
# LA     51
# PA     45
# IA     44
# CA     34
# Name: State, dtype: int64
#
# AK

# %%
churn['International plan']
# Out:
# 0       No
# 1       No
# 2       No
# 3       No
# 4       No
#         ..
# 2661    No
# 2662    No
# 2663    No
# 2664    No
# 2665    No
# Name: International plan, Length: 3333, dtype: object
